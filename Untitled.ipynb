# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/home/itnepal/Downloads/realpy-materials-master/BL-Flickr-Images-Book.csv')

to_drop = ['Edition Statement',
           'Corporate Author',
           'Corporate Contributors',
           'Former owner',
           'Engraver',
           'Contributors',
           'Issuance type',
           'Shelfmarks']

df.drop(to_drop, inplace=True, axis=1)

df.head(20)
# Out:
#     Identifier                 Place of Publication Date of Publication  \
# 0          206                               London         1879 [1878]
# 1          216             London; Virtue & Yorston                1868
# 2          218                               London                1869
# 3          472                               London                1851
# 4          480                               London                1857
# 5          481                               London                1875
# 6          519                               London                1872
# 7          667  pp. 40. G. Bryan & Co: Oxford, 1898                 NaN
# 8          874                              London]                1676
# 9         1143                               London                1679
# 10        1280                             Coventry                1802
# 11        1808                          Christiania                1859
# ...

# %%
df.set_index('Identifier', inplace = True)

# %%
#extr = df['Date of Publication'].str.extract(r'^(\d{4})', expand = False)

df['Date of Publication'] = pd.to_numeric(extr)
df['Place of Publication'].head(10)
# Out:
# Identifier
# 206                                  London
# 216                London; Virtue & Yorston
# 218                                  London
# 472                                  London
# 480                                  London
# 481                                  London
# 519                                  London
# 667     pp. 40. G. Bryan & Co: Oxford, 1898
# 874                                 London]
# 1143                                 London
# Name: Place of Publication, dtype: object

# %%
london = df['Place of Publication'].str.contains('London')
oxford = df['Place of Publication'].str.contains('Oxford')

# %%
df['Place of Publication'] = np.where(london, 'London',
                                      np.where(oxford, 'Oxford',
                                               df['Place of Publication'].str.replace('-', ' ')))

# %%
df.shape
# Out:
# (8287, 6)

# %%
university_towns = []
with open('/home/itnepal/Downloads/realpy-materials-master/university_towns.txt') as file:
    for line in file:
        if '[edit]' in line:
            # Remember this `state` until the next is found
            state = line
        else:
            # Otherwise, we have a city; keep `state` as last-seen
            university_towns.append((state, line))
university_towns[:25]

# %%
df = pd.DataFrame(university_towns, columns = ['state','RegionName'])
df
# Out:
#                  state                                         RegionName
# 0      Alabama[edit]\n                    Auburn (Auburn University)[1]\n
# 1      Alabama[edit]\n           Florence (University of North Alabama)\n
# 2      Alabama[edit]\n  Jacksonville (Jacksonville State University)[2]\n
# 3      Alabama[edit]\n       Livingston (University of West Alabama)[2]\n
# 4      Alabama[edit]\n         Montevallo (University of Montevallo)[2]\n
# ..                 ...                                                ...
# 512  Wisconsin[edit]\n  River Falls (University of Wisconsin–River Fal...
# 513  Wisconsin[edit]\n  Stevens Point (University of Wisconsin–Stevens...
# 514  Wisconsin[edit]\n                    Waukesha (Carroll University)\n
# 515  Wisconsin[edit]\n  Whitewater (University of Wisconsin–Whitewater...
# 516    Wyoming[edit]\n               Laramie (University of Wyoming)[5]\n
#
# [517 rows x 2 columns]

# %%
def get_citystate(item):
    if ' (' in item:
        return item[:item.find(' (')]
    elif '[' in item:
        return item[:item.find('[')]
    else:
        return item
df.applymap(get_citystate)
# Out:
#          state     RegionName
# 0      Alabama         Auburn
# 1      Alabama       Florence
# 2      Alabama   Jacksonville
# 3      Alabama     Livingston
# 4      Alabama     Montevallo
# ..         ...            ...
# 512  Wisconsin    River Falls
# 513  Wisconsin  Stevens Point
# 514  Wisconsin       Waukesha
# 515  Wisconsin     Whitewater
# 516    Wyoming        Laramie
#
# [517 rows x 2 columns]
